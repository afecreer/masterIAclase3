# %% [markdown]
# Taller integrador

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import pandas as pd
#print(pd.__version__)
#df = pd.read_csv("estudiantes.csv")
#df
# Out:
#     id            nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1       Laura Gómez    42      Medellín               0       8.3    True
# 1    2      Carlos Pérez    29          Cali               1       7.9    True
# 2    3        Anita Ruiz    40       Pereira               0       3.7    True
# 3    4       Juan Torres    29        Bogotá               8       4.8   False
# 4    5       María López    29     Manizales               4       8.8    True
# 5    6     Andrés Castro    27       Pereira               5       5.3    True
# 6    7     Sofía Herrera    32      Medellín               1       6.0    True
# 7    8    Diego Martínez    33     Cartagena               0       8.2    True
# 8    9    Valentina Ríos    34      Medellín               8       5.4    True
# 9   10       Felipe Mora    40  Barranquilla               1       3.8    True
# 10  11     Camila Vargas    31      Medellín               3       9.1   False
# ...

# %% [markdown]
# Pandas libreria de python
# Dataframe estrucctura que crean pandas cuando carga un csv, tiene por lo general filas y columnas

# %%
#print(df.shape)
#print(df.columns.tolist())
#df["nombre"]
#print(df.loc[0, "nombre"])
#print(df.loc[0, "promedio"])
#ver el ultimo nombre
#print(df.loc[df.shape[0] -1, "nombre"])
#df.head(10)
#saca estadisticas
#df.describe()
# Out:
#              id       edad  cursos_previos   promedio
# count  20.00000  20.000000       20.000000  20.000000
# mean   10.50000  34.100000        3.100000   6.705000
# std     5.91608   5.901828        2.531902   1.814409
# min     1.00000  27.000000        0.000000   3.700000
# 25%     5.75000  29.000000        1.000000   5.275000
# 50%    10.50000  32.500000        2.500000   6.650000
# 75%    15.25000  40.000000        5.000000   8.225000
# max    20.00000  45.000000        8.000000   9.300000

# %%
df.where(df["promedio"] > 8).dropna()
# Out:
#       id           nombre  edad        ciudad  cursos_previos  promedio activo
# 0    1.0      Laura Gómez  42.0      Medellín             0.0       8.3   True
# 4    5.0      María López  29.0     Manizales             4.0       8.8   True
# 7    8.0   Diego Martínez  33.0     Cartagena             0.0       8.2   True
# 10  11.0    Camila Vargas  31.0      Medellín             3.0       9.1  False
# 14  15.0  Lucía Fernández  42.0  Barranquilla             5.0       9.0   True
# 18  19.0    Natalia Reyes  45.0     Cartagena             6.0       9.3  False

# %%
df[(df['promedio'] >= 8)&(df['activo'] == True)]
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 4    5      María López    29     Manizales               4       8.8    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True

# %%
df[(df["promedio"] >= 8) & (df["activo"] == True)]
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 4    5      María López    29     Manizales               4       8.8    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True

# %%
# Mostrar las personas que tengan el promedio mayor que 8

df[df["promedio"] >= 8.0]
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 4    5      María López    29     Manizales               4       8.8    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 10  11    Camila Vargas    31      Medellín               3       9.1   False
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True
# 18  19    Natalia Reyes    45     Cartagena               6       9.3   False

# %%
#limipiar data set con critierio
df.isnull().sum()
# Out:
# id                0
# nombre            0
# edad              0
# ciudad            0
# cursos_previos    0
# promedio          0
# activo            0
# dtype: int64

# %%
import pandas as pd
#print(pd.__version__)
df = pd.read_csv("estudiantes_ml_2026_.csv")
df
# Out:
#                nombre  edad            ciudad       pais genero nivel_previo  \
# 0    Valentina Torres    28            Bogotá   Colombia      F   intermedio
# 1      Carlos Mendoza    34  Ciudad de México     México      M       básico
# 2          Anita Ruiz    25          Medellín   Colombia      F       básico
# 3       Jorge Ramírez    41              Lima       Perú      M     avanzado
# 4        Daniela Soto    29          Santiago      Chile      F   intermedio
# 5       Miguel Flores    37       Guadalajara     México      M       básico
# 6         Laura Gómez    31              Cali   Colombia      F       básico
# 7    Sebastián Castro    26      Buenos Aires  Argentina      M   intermedio
# 8       Camila Vargas    33             Quito    Ecuador      F       básico
# 9      Andrés Herrera    45      Barranquilla   Colombia      M     avanzado
# 10      Paula Jiménez    27        Montevideo    Uruguay      F       básico
# ...

# %%
df.isnull().sum()
# Out:
# nombre                  0
# edad                    0
# ciudad                  0
# pais                    0
# genero                  0
# nivel_previo            0
# horas_estudio_semana    0
# promedio                2
# modulos_completados     0
# activo                  0
# fecha_ingreso           0
# trabaja_actualmente     0
# salario_usd             0
# objetivo                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nombre                25 non-null     object
#  1   edad                  25 non-null     int64
#  2   ciudad                25 non-null     object
#  3   pais                  25 non-null     object
#  4   genero                25 non-null     object
#  5   nivel_previo          25 non-null     object
#  6   horas_estudio_semana  25 non-null     int64
#  7   promedio              23 non-null     float64
#  8   modulos_completados   25 non-null     int64
#  9   activo                25 non-null     bool
#  10  fecha_ingreso         25 non-null     object
#  11  trabaja_actualmente   25 non-null     bool
#  12  salario_usd           25 non-null     int64
#  13  objetivo              25 non-null     object
# dtypes: bool(2), float64(1), int64(4), object(7)
# ...

# %%
import pandas as pd
#print(pd.__version__)
df = pd.read_csv("titanic_clase4.csv")
df
# Out:
#              nombre  sobrevivio  clase    sexo  edad  tarifa embarcacion  \
# 0       Jack Dawson           0      3    male  20.0    7.25           S
# 1       Rose DeWitt           1      1  female  17.0  512.33           C
# 2        John Smith           0      2    male  35.0   13.00           S
# 3      Mary Johnson           1      1  female  28.0   76.29           C
# 4      Thomas Brown           0      3    male   NaN    8.05           S
# 5   Elisabeth Jones           1      1  female  45.0   35.50           S
# 6     William Davis           0      3    male  23.0    7.92           Q
# 7      Sarah Wilson           1      2  female  31.0   21.00           S
# 8      James Miller           0      3    male   NaN    7.75           Q
# 9        Emma Moore           1      1  female  22.0  151.55           S
# 10    Robert Taylor           1      1    male  42.0   52.00           S
# 11    Anna Anderson           1      3  female  26.0    7.92           S
# ...

# %%
#resumen de la informacion del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nombre       31 non-null     object
#  1   sobrevivio   31 non-null     int64
#  2   clase        31 non-null     int64
#  3   sexo         31 non-null     object
#  4   edad         27 non-null     float64
#  5   tarifa       31 non-null     float64
#  6   embarcacion  31 non-null     object
#  7   cabina       11 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#        sobrevivio      clase       edad      tarifa
# count   31.000000  31.000000  27.000000   31.000000
# mean     0.516129   2.129032  33.222222   52.375161
# std      0.508001   0.921663  11.056962   98.678691
# min      0.000000   1.000000  17.000000    7.250000
# 25%      0.000000   1.000000  25.000000    7.920000
# 50%      1.000000   2.000000  33.000000   13.000000
# 75%      1.000000   3.000000  39.000000   55.700000
# max      1.000000   3.000000  62.000000  512.330000

# %%
titanic_nuevo=df.drop(columns=["cabina"])
titanic_nuevo=df.drop_duplicates()
media_edad=titanic_nuevo["edad"].median()
titanic_nuevo["edad"].fillna(media_edad)
print(f"info_limpia: {titanic_nuevo.shape}")
# Out:
# info_limpia: (30, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nombre       31 non-null     object
#  1   sobrevivio   31 non-null     int64
#  2   clase        31 non-null     int64
#  3   sexo         31 non-null     object
#  4   edad         27 non-null     float64
#  5   tarifa       31 non-null     float64
#  6   embarcacion  31 non-null     object
#  7   cabina       11 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.1+ KB

# %%
#tasa=titanic_nuevo["sobrevivio"]
#print(f"Tasa de supervivencia es:{tasa:0%}")
#sobrevivieron mas hombres o mujeres
titanic_nuevo.groupby("sexo")["sobrevivio"].mean()
# Out:
# sexo
# female    0.933333
# male      0.133333
# Name: sobrevivio, dtype: float64

# %%
#la clase determino la supervivencia?
titanic_nuevo.groupby("clase")["sobrevivio"].mean()
# Out:
# clase
# 1    1.000000
# 2    0.750000
# 3    0.133333
# Name: sobrevivio, dtype: float64

# %% [markdown]
# matplotlib para hace gráficas

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
supervivencia_sexo=titanic_nuevo.groupby("sexo")["sobrevivio"].mean()
plt.figure(figsize=(7,5))
supervivencia_sexo.plot(
    kind="bar",
    color=["#DD8452","#3062B8"],
    edgecolor ="white",
    width=0.5
)
plt.title("Supervivencia por sexo", fontsize=14, fontweight="bold")
# Out:
# <Axes: xlabel='sexo'>

# %%
supervivencia_clase=titanic_nuevo.groupby("clase")["sobrevivio"].mean()
plt.figure(figsize=(7,5))
supervivencia_clase.plot(
    kind="bar",
    color=["#E8EE3B","#0D7643","#5DEE1A"],
    edgecolor ="white",
    width=0.5
)
plt.title("Supervivencia por clase", fontsize=14, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Supervivencia por clase')
